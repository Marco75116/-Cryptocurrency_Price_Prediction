# %% [markdown]
# <a href="https://colab.research.google.com/github/Marco75116/-Cryptocurrency_Price_Prediction/blob/main/GRU.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %tensorflow_version 2.x
import json
import requests
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout, LSTM, GRU
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.metrics import mean_absolute_error,mean_squared_error

# %%
endpoint = 'https://min-api.cryptocompare.com/data/histoday'
res = requests.get(endpoint + '?fsym=ETH&tsym=EUR&limit=500')
hist = pd.DataFrame(json.loads(res.content)['Data'])
hist = hist.set_index('time')
hist.index = pd.to_datetime(hist.index, unit='s')
# colonne cible
target_col = 'close'
# maj API, suppression des 2 colonnes string
hist_eth = hist.drop(['conversionType','conversionSymbol'], axis=1)

# %%
endpoint = 'https://min-api.cryptocompare.com/data/histoday'
res = requests.get(endpoint + '?fsym=BTC&tsym=EUR&limit=500')
hist = pd.DataFrame(json.loads(res.content)['Data'])
hist = hist.set_index('time')
hist.index = pd.to_datetime(hist.index, unit='s')
# colonne cible
target_col = 'close'
# maj API, suppression des 2 colonnes string
hist_btc = hist.drop(['conversionType','conversionSymbol'], axis=1)

# %%
df = pd.DataFrame({'BTC': hist_btc.close,
                   'ETH': hist_eth.close})
df.head(10)
# Out:
#                  BTC     ETH
# time
# 2020-08-25   9594.61  324.59
# 2020-08-26   9693.73  326.29
# 2020-08-27   9595.58  324.33
# 2020-08-28   9705.52  332.80
# 2020-08-29   9668.58  335.98
# 2020-08-30   9838.41  360.38
# 2020-08-31   9783.75  364.35
# 2020-09-01  10008.41  399.44
# 2020-09-02   9641.23  372.06
# 2020-09-03   8626.47  324.36

# %%
np.random.seed(7)
dataset = df.values
# normalize the dataset
from sklearn.preprocessing import MinMaxScaler
scaler_btc = MinMaxScaler(feature_range=(0, 1))
scaler_eth = MinMaxScaler(feature_range=(0, 1))
dataset[:,0] = scaler_btc.fit_transform(dataset[:,0].reshape(-1,1)).reshape(-1)
dataset[:,1] = scaler_eth.fit_transform(dataset[:,1].reshape(-1,1)).reshape(-1)

# %%
np.random.seed(42)
# HYPER PARAMTERS 
window_len = 5
zero_base = True
lstm_neurons = 100
epochs = 200
batch_size = 16
loss = 'mean_squared_error'
dropout = 0
optimizer = 'adam'

# %%
def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back - 1):
        a = dataset[i:(i + look_back), :]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 1])
    return np.array(dataX), np.array(dataY)

# %%
# split into train and test sets
train_size = int(len(dataset) * 0.67) 
test_size = len(dataset) - train_size
train, test = dataset[0:train_size, :], dataset[train_size:len(dataset), :]

# %%
trainX, trainY = create_dataset(train, window_len)  
testX, testY   = create_dataset(test, window_len)

# %%
trainX.shape
# Out:
# (329, 5, 2)

# %%
def build_lstm_model(input_data, output_size, neurons=100, activ_func='linear', dropout=0.2, loss='mse', optimizer='adam'):
    model = Sequential()
    model.add(GRU(neurons, input_shape=( input_data.shape[1], input_data.shape[2] )    ))
    model.add(Dense(output_size))
    # model.add(Dropout(dropout))
    model.compile(loss=loss, optimizer=optimizer)
    return model

# %%
trainX = np.reshape(trainX, (trainX.shape[0], window_len, 2))
testX  = np.reshape(testX, (testX.shape[0],window_len, 2))

# %%
model = build_lstm_model(trainX,output_size=1,neurons=lstm_neurons,dropout=dropout,optimizer=optimizer)

# %%
history= model.fit(trainX, trainY,validation_split=0.33, epochs=epochs, batch_size=batch_size)
# Out:
# Epoch 1/200
# 14/14 [==============================] - 3s 53ms/step - loss: 0.0339 - val_loss: 0.0227
# Epoch 2/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0062 - val_loss: 0.0500
# Epoch 3/200
# 14/14 [==============================] - 0s 10ms/step - loss: 0.0016 - val_loss: 0.0359
# Epoch 4/200
# 14/14 [==============================] - 0s 9ms/step - loss: 7.7898e-04 - val_loss: 0.0263
# Epoch 5/200
# 14/14 [==============================] - 0s 10ms/step - loss: 7.5916e-04 - val_loss: 0.0313
# Epoch 6/200
# 14/14 [==============================] - 0s 10ms/step - loss: 6.6670e-04 - val_loss: 0.0278
# Epoch 7/200
# 14/14 [==============================] - 0s 10ms/step - loss: 6.2553e-04 - val_loss: 0.0267
# Epoch 8/200
200
# 14/14 [==============================] - 0s 9ms/step - loss: 1.6229e-04 - val_loss: 0.0017
# Epoch 158/200
# 14/14 [==============================] - 0s 10ms/step - loss: 1.6129e-04 - val_loss: 0.0016
# Epoch 159/200
# 14/14 [==============================] - 0s 10ms/step - loss: 1.5014e-04 - val_loss: 0.0018
# Epoch 160/200
# 14/14 [==============================] - 0s 11ms/step - loss: 1.5750e-04 - val_loss: 0.0016
# Epoch 161/200
# 14/14 [==============================] - 0s 10ms/step - loss: 1.9595e-04 - val_loss: 0.0020
# Epoch 162/200
# 14/14 [==============================] - 0s 10ms/step - loss: 1.9016e-04 - val_loss: 0.0016
# Epoch 163/200
# 14/14 [==============================] - 0s 9ms/step - loss: 1.8437e-04 - val_loss: 0.0014
# Epoch 164/200
# 14/14 [==============================] - 0s 10ms/step - loss: 1.7800e-04 - val_loss: 0.0017
# Epoch 165/200
# 14/14 [==============================] - 0s 9ms/step - loss: 1.6525e-04 - val_loss: 0.0021
# Epoch 166/200
# 14/14 [==============================] - 0s 13ms/step - loss: 1.7117e-04 - val_loss: 0.0016
# Epoch 167/200
# 14/14 [==============================] - 0s 10ms/step - loss: 1.6236e-04 - val_loss: 0.0021
# Epoch 168/200
# 14/14 [==============================] - 0s 10ms/step - loss: 1.8787e-04 - val_loss: 0.0020
# Epoch 169/200
# 14/14 [==============================] - 0s 11ms/step - loss: 1.5606e-04 - val_loss: 0.0020
# Epoch 170/200
# 14/14 [==============================] - 0s 11ms/step - loss: 1.6122e-04 - val_loss: 0.0017
# Epoch 171/200
# 14/14 [==============================] - 0s 10ms/step - loss: 1.6933e-04 - val_loss: 0.0018
# Epoch 172/200
# 14/14 [==============================] - 0s 11ms/step - loss: 1.6729e-04 - val_loss: 0.0015
# Epoch 173/200
# 14/14 [==============================] - 0s 11ms/step - loss: 1.8275e-04 - val_loss: 0.0015
# Epoch 174/200
# 14/14 [==============================] - 0s 10ms/step - loss: 1.6251e-04 - val_loss: 0.0020
# Epoch 175/200
# 14/14 [==============================] - 0s 11ms/step - loss: 2.1275e-04 - val_loss: 0.0018
# Epoch 176/200
# 14/14 [==============================] - 0s 10ms/step - loss: 1.9882e-04 - val_loss: 0.0016
# Epoch 177/200
# 14/14 [==============================] - 0s 10ms/step - loss: 1.7385e-04 - val_loss: 0.0016
# Epoch 178/200
# 14/14 [==============================] - 0s 10ms/step - loss: 1.8575e-04 - val_loss: 0.0014
# Epoch 179/200
# 14/14 [==============================] - 0s 9ms/step - loss: 1.6854e-04 - val_loss: 0.0018
# Epoch 180/200
# 14/14 [==============================] - 0s 10ms/step - loss: 1.5548e-04 - val_loss: 0.0015
# Epoch 181/200
# 14/14 [==============================] - 0s 9ms/step - loss: 1.6948e-04 - val_loss: 0.0017
# Epoch 182/200
# 14/14 [==============================] - 0s 10ms/step - loss: 1.5498e-04 - val_loss: 0.0018
# Epoch 183/200
# 14/14 [==============================] - 0s 9ms/step - loss: 1.5836e-04 - val_loss: 0.0016
# Epoch 184/200
# 14/14 [==============================] - 0s 9ms/step - loss: 1.7276e-04 - val_loss: 0.0022
# Epoch 185/200
# 14/14 [==============================] - 0s 10ms/step - loss: 1.9032e-04 - val_loss: 0.0017
# Epoch 186/200
# 14/14 [==============================] - 0s 11ms/step - loss: 1.9278e-04 - val_loss: 0.0015
# Epoch 187/200
# 14/14 [==============================] - 0s 11ms/step - loss: 1.7653e-04 - val_loss: 0.0016
# Epoch 188/200
# 14/14 [==============================] - 0s 10ms/step - loss: 1.6338e-04 - val_loss: 0.0019
# Epoch 189/200
# 14/14 [==============================] - 0s 10ms/step - loss: 1.5145e-04 - val_loss: 0.0019
# Epoch 190/200
# 14/14 [==============================] - 0s 10ms/step - loss: 1.5805e-04 - val_loss: 0.0016
# Epoch 191/200
# 14/14 [==============================] - 0s 12ms/step - loss: 1.5863e-04 - val_loss: 0.0016
# Epoch 192/200
# 14/14 [==============================] - 0s 11ms/step - loss: 1.6063e-04 - val_loss: 0.0021
# Epoch 193/200
# 14/14 [==============================] - 0s 10ms/step - loss: 1.6135e-04 - val_loss: 0.0016
# Epoch 194/200
# 14/14 [==============================] - 0s 12ms/step - loss: 1.6244e-04 - val_loss: 0.0015
# Epoch 195/200
# 14/14 [==============================] - 0s 10ms/step - loss: 1.6125e-04 - val_loss: 0.0015
# Epoch 196/200
# 14/14 [==============================] - 0s 12ms/step - loss: 1.5031e-04 - val_loss: 0.0018
# Epoch 197/200
# 14/14 [==============================] - 0s 12ms/step - loss: 1.6174e-04 - val_loss: 0.0017
# Epoch 198/200
# 14/14 [==============================] - 0s 12ms/step - loss: 1.8799e-04 - val_loss: 0.0016
# Epoch 199/200
# 14/14 [==============================] - 0s 11ms/step - loss: 1.6677e-04 - val_loss: 0.0015
# Epoch 200/200
# 14/14 [==============================] - 0s 13ms/step - loss: 1.6102e-04 - val_loss: 0.0014

# %%
# Plot training
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('model loss')
plt.ylabel('Error')
plt.xlabel('Epochs')
plt.legend(['Train', 'validation'], loc='upper right')
plt.show()

# %%
# make predictions
testPredict = model.predict(testX)

# %%
testY_o = scaler_eth.inverse_transform(testY.reshape(-1, 1))
testPredict_o = scaler_eth.inverse_transform(testPredict)

testScore  = mean_absolute_error(testY_o, testPredict_o)
print('Test Score: %.2f MAE' % (testScore))
# Out:
# Test Score: 129.09 MAE

# %%
def line_plot(line1, line2, label1=None, label2=None, title='', lw=2):
    fig, ax = plt.subplots(1, figsize=(13, 7))
    ax.plot(line1, label=label1, linewidth=lw)
    ax.plot(line2, label=label2, linewidth=lw)
    ax.set_ylabel('prix [EUR]', fontsize=14)
    ax.set_title(title, fontsize=16)
    ax.legend(loc='best', fontsize=16)

# %%
line_plot(testY_o, testPredict_o, 'actual', 'prediction', lw=3)
